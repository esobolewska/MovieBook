# %% [markdown]
# # IMDb Webscraping using BeautifulSoup
# ### 1. Importing necessary libraries

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from time import sleep
import re
import pandas as pd
import sqlite3

# %% [markdown]
# ### 2. Getting html of IMDb Top 250 movies

# %%
movie_url = 'https://www.imdb.com/chart/top?ref_=nv_mv_250'
uClient = uReq(movie_url)
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html, "html.parser")

# %% [markdown]
# ### 3. Creating list of links to film pages

# %%
page_list = []
for i in page_soup.findAll("td",{"class":"titleColumn"}):
    page_list.append(i.a['href'])

# %%
len(page_list)
# Out:
# 250

# %% [markdown]
# ### 4. Scraping 250 films
# \* _The try function has been put because not all films have all components. This can be avoided through determining which elements cause errors and decide on how to fill missing values, but because this was a test database, we decided to ommit the ones that caused problems. This resulted in info on 239 films._

# %%
film_items = []

for l in page_list:
    link = 'https://imdb.com'+ l
    uClient = uReq(link)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    
    try:
        pl_title = page_soup.title.string[:-14]
        title = str(page_soup.find('div',{'class':'originalTitle'}))[27:-56]

        print(title)

        if title=='':
            title=pl_title
            print('zmiana',title)

        id_title = '-'.join(re.split(r'\W+', title.lower()))
        description = page_soup.find('div',{'class':'summary_text'}).string.strip()
        year = page_soup.title.string[-12:-8]
        time = page_soup.time.string.strip()
        genre = page_soup.find('div',{'class':'title_wrapper'}).findAll('a')[1].string
        poster_url = page_soup.find('div',{'class':'poster'}).img['src']
        film_items.append((pl_title, title, id_title, description, year, time, genre, poster_url))

        for i in page_soup.findAll('div',{'class':'credit_summary_item'}):
            if i.h4.string=='Stars:':
                film_stars=[]
                for j in i.findAll('a')[:-1]:  
                    film_stars.append(j.string)
                film_stars=", ".join(film_stars)
            else:
                film_items[-1] = film_items[-1] + (str(i.a.string),)
        film_items[-1] = (None, ) + film_items[-1] + (film_stars,)
    except Exception:

        pl_title = page_soup.title.string[:-14]
        title = str(page_soup.find('div',{'class':'originalTitle'}))[27:-56]
        print('nie dziala', pl_title, title)
# Out:
# One Flew Over the Cuckoo's Nest
# Goodfellas
# The Matrix
# Shichinin no samurai
# Cidade de Deus
# Se7en
# Star Wars
# The Silence of the Lambs
# It's a Wonderful Life
# La vita è bella
# The Usual Suspects
# Sen to Chihiro no kamikakushi
# Saving Private Ryan
# Spider-Man: Into the Spider-Verse
# Léon
# The Green Mile
#
# zmiana Interstellar
# Psycho
# American History X
# City Lights
# C'era una volta il West
#
# zmiana Casablanca
# Modern Times
# The Pianist
# Intouchables
# The Departed
# Terminator 2: Judgment Day
# Back to the Future
#
# zmiana Whiplash
# Rear Window
# Raiders of the Lost Ark
# nie dziala Poszukiwacze zaginionej arki Raiders of the Lost Ark
# The Lion King
#
# zmiana Gladiator
# The Prestige
# Apocalypse Now
#
# zmiana Memento
# Alien
# The Great Dictator
# Nuovo Cinema Paradiso
# Hotaru no haka
# Avengers: Infinity War
# Sunset Blvd.
# Das Leben der Anderen
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Paths of Glory
# The Shining
# Django Unchained
#
# zmiana WALL·E
# Mononoke-hime
# Witness for the Prosecution
#
# zmiana American Beauty
# The Dark Knight Rises
# Oldeuboi
# Aliens
# Once Upon a Time in America
#
# zmiana Coco
# Das Boot
# Citizen Kane
# Braveheart
# Vertigo
# North by Northwest
# Reservoir Dogs
# Star Wars: Episode VI - Return of the Jedi
# M - Eine Stadt sucht einen Mörder
#
# zmiana Kimi no na wa.
# Amadeus
# Requiem for a Dream
#
# zmiana Dangal
# nie dziala Dangal
# Taare Zameen Par
# Lawrence of Arabia
# nie dziala Lawrence z Arabii Lawrence of Arabia
# Eternal Sunshine of the Spotless Mind
# A Clockwork Orange
# 3 Idiots
# 2001: A Space Odyssey
# Le fabuleux destin d'Amélie Poulain
#
# zmiana Toy Story
# Double Indemnity
# Taxi Driver
# Singin' in the Rain
# Inglourious Basterds
#
# zmiana Full Metal Jacket
# To Kill a Mockingbird
# Ladri di biciclette
# The Kid
# The Sting
# Good Will Hunting
#
# zmiana Toy Story 3
# Jagten
# Snatch
# Scarface
# Monty Python and the Holy Grail
# Per qualche dollaro in più
# L.A. Confidential
# The Apartment
#
# zmiana Metropolis
# Jodaeiye Nader az Simin
# Indiana Jones and the Last Crusade
# nie dziala Indiana Jones i ostatnia krucjata Indiana Jones and the Last Crusade
# Rashômon
# Up
# All About Eve
# Batman Begins
# Yôjinbô
# Some Like It Hot
# Unforgiven
# Der Untergang
# Die Hard
# The Treasure of the Sierra Madre
# Heat
# Ikiru
# Incendies
# Raging Bull
# nie dziala Wściekły byk Raging Bull
# The Great Escape
# Bacheha-Ye aseman
# El laberinto del fauno
# Babam ve Oglum
#
# zmiana Chinatown
# The Third Man
#
# zmiana Bohemian Rhapsody
# nie dziala Bohemian Rhapsody
# Tonari no Totoro
# Hauru no ugoku shiro
#
# zmiana Ran
# Judgment at Nuremberg
# El secreto de sus ojos
# The Gold Rush
# The Bridge on the River Kwai
# A Beautiful Mind
# nie dziala Piękny umysł A Beautiful Mind
# Lock, Stock and Two Smoking Barrels
# Casino
# Three Billboards Outside Ebbing, Missouri
# On the Waterfront
# Det sjunde inseglet
# Inside Out
# The Elephant Man
# Room
# The Wolf of Wall Street
# nie dziala Wilk z Wall Street The Wolf of Wall Street
# Mr. Smith Goes to Washington
# V for Vendetta
# Warrior
# Blade Runner
# Dial M for Murder
# Smultronstället
# The General
# No Country for Old Men
#
# zmiana Trainspotting
# There Will Be Blood
# The Sixth Sense
# Gone with the Wind
# The Thing
#
# zmiana Fargo
#
# zmiana Gran Torino
# The Deer Hunter
# Finding Nemo
# Idi i smotri
# The Big Lebowski
# Sherlock Jr.
# Shutter Island
# Kill Bill: Vol. 1
# Cool Hand Luke
#
# zmiana Roma
# Rebecca
# Tôkyô monogatari
# Mary and Max
# Hacksaw Ridge
# nie dziala Przełęcz ocalonych Hacksaw Ridge
# Gone Girl
# How to Train Your Dragon
# Sunrise: A Song of Two Humans
# Relatos salvajes
# Jurassic Park
# Into the Wild
# Life of Brian
# In the Name of the Father
# The Truman Show
# The Grand Budapest Hotel
# Platoon
# It Happened One Night
# Stand by Me
# Eskiya
# Network
#
# zmiana Stalker
#
# zmiana Persona
# Salinui chueok
# Ben-Hur
# Hotel Rwanda
# 12 Years a Slave
# nie dziala Zniewolony: 12 Years a Slave 12 Years a Slave
# Million Dollar Baby
# Andrey Rublev
# Rush
# nie dziala Wyścig Rush
# La passion de Jeanne d'Arc
# Le salaire de la peur
# Before Sunrise
# Mad Max: Fury Road
# Les quatre cents coups
# Prisoners
# Hachi: A Dog's Tale
#
# zmiana Spotlight
# Logan
# Rang De Basanti
#
# zmiana Amores perros
# The Princess Bride
# Catch Me If You Can
# Kaze no tani no Naushika
# Harry Potter and the Deathly Hallows: Part 2
# Butch Cassidy and the Sundance Kid
#
# zmiana Rocky
#
# zmiana Barry Lyndon
# Monsters, Inc.
# The Grapes of Wrath
# The Maltese Falcon
# Dead Poets Society
#
# zmiana Donnie Darko
# The Terminator
#
# zmiana Gandhi
# Les diaboliques
# La haine
# Groundhog Day
# The Wizard of Oz
# Jaws
# Le notti di Cabiria
# The Help
# Faa yeung nin wa
# Mandariinid
# Tsubaki Sanjûrô
# Before Sunset
# Paper Moon
# Ah-ga-ssi
# Paris, Texas
# Tenkû no shiro Rapyuta
# The Best Years of Our Lives
# Pirates of the Caribbean: The Curse of the Black Pearl
# Fanny och Alexander
# Guardians of the Galaxy
#
# zmiana Gangs of Wasseypur
#
# zmiana La La Land
#
# zmiana Blade Runner 2049
# 8½

# %% [markdown]
# ### 5. Inserting scraped films into database

# %%
conn = sqlite3.connect('project.db')
c = conn.cursor()
c.executemany('INSERT INTO films VALUES (?,?,?,?,?,?,?,?,?,?,?,?)', film_items)
conn.commit()
conn.close()

# %% [markdown]
# ### 6. Viewing added films

# %%
conn = sqlite3.connect('project.db')
c = conn.cursor()
c.execute('SELECT * FROM films')

listOfResults=c.fetchall()
film_dataframe = pd.DataFrame(listOfResults)

conn.commit()
conn.close()

film_dataframe.columns=['id_film','name','pl_title','title','description','year','time','genre','poster_url','director','writer','stars']
film_dataframe.index=film_dataframe.index+1
film_dataframe.loc[1,:]
# Out:
# id_film                                                        1
# name                                        Skazani na Shawshank
# pl_title                                The Shawshank Redemption
# title                                   the-shawshank-redemption
# description    Two imprisoned men bond over a number of years...
# year                                                        1994
# time                                                    2h 22min
# genre                                                      Drama
# poster_url     https://m.media-amazon.com/images/M/MV5BMDFkYT...
# director                                          Frank Darabont
# writer                                              Stephen King
# stars                    Tim Robbins, Morgan Freeman, Bob Gunton
# Name: 1, dtype: object
